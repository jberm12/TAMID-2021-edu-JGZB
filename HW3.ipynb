# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('/Users/jonahberman/Desktop/TAMID/College-Football-Original-Dataset-Raw_Data.csv', header = 1)

# %%
df = df.dropna()

# %%
df['RUN_PERCENT'] = pd.to_numeric(df['RUN_PERCENT'].str.replace('%', ''))
df['PASS_PERCENT'] = pd.to_numeric(df['PASS_PERCENT'].str.replace('%', ''))
df
# Out:
#      UniversityName  Year        TeamID  CMP  ATT    YDS  CMPPercent  YPA  \
# 0          AirForce  2010  AirForce2010   88  168  1,551        52.4  9.2
# 1          AirForce  2011  AirForce2011  123  204  1,821        60.3  8.9
# 2          AirForce  2012  AirForce2012   83  151  1,334        55.0  8.8
# 3          AirForce  2013  AirForce2013   93  174  1,259        53.4  7.2
# 4          AirForce  2014  AirForce2014  117  206  1,893        56.8  9.2
# ...             ...   ...           ...  ...  ...    ...         ...  ...
# 1367        Wyoming  2016   Wyoming2016  210  379  3,207        55.4  8.5
# 1368        Wyoming  2017   Wyoming2017  195  348  2,304        56.0  6.6
# 1369        Wyoming  2018   Wyoming2018  135  276  1,576        48.9  5.7
# 1370        Wyoming  2019   Wyoming2019  120  256  1,770        46.9  6.9
# 1371        Wyoming  2020   Wyoming2020   62  134    920        46.3  6.0
#
#       LNG  TD  INT  SACK  SYL    RTG  R_ATT  R_AVG  TOTAL_PLAYS  RUN_PERCENT  \
# ...

# %%
df2 = df[['CMPPercent', 'PASS_PERCENT']]
df2.corr()
# Out:
#               CMPPercent  PASS_PERCENT
# CMPPercent      1.000000      0.362311
# PASS_PERCENT    0.362311      1.000000

# %%
df2.plot()
# Out:
# <AxesSubplot:>
